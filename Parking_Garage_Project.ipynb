# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
from re import S
# Your Code will go here
#Step 1 make class
#Step 2 init all 3 attributes (with self)
#Step 3 Create 3 methods
#Step 3 a) start function takeTicket
#Step 3 b) decrease tickets
#Step 3 c) decrease parkingSpaces
#Step 3 d) start function payForParking
#Step 3 e) input for integers
#Step 3 f) print message (see assignment for details)
#Step 3 g) set current ticket (dict) to True
#Step 3 h) start function leaveGarage
#Step 3 i) if paid print thank you
#Step 3 j) if not paid request payment then loop back to i
#Step 3 k) increase parkingSpaces
#Step 3 L) increase tickets
#Step 4 make master function
#Step 5 if's to run through steps
#Step 6 run function

#Parking Garage object
class Parking_Garage:
  ''' Parking Garage has 3 attributes, tickets, parkingSpaces, and currentTicket
  tickets are expected to be an list
  parkingSpaces are expected to be an list
  currentTicket are expected to be an dictionary'''
  def __init__(self, tickets = [0,1,2], parkingSpaces = [0,1,2], currentTicket = {'paid' : False}):
    self.tickets = tickets
    self.parkingSpaces = parkingSpaces
    self.currentTicket = currentTicket

  def takeTicket(self): # may want a counter function
    self.tickets.pop(0)
    self.parkingSpaces.pop(0)
    print(self.tickets)
    print(self.parkingSpaces)

  def payforParking(self):
    cost = "" # This may not be needed
    cost = (input("$'s paid for ticket? (Please type a number.): "))
    if cost == True: #maybe swap this to continue if type float
      print("Thank you for paying, you have 15 minutes to leave")
    else:
      pass
    self.currentTicket['paid'] = True

  def leaveGarage(self):
    if self.currentTicket['paid'] == True: #this may want a counter function
      print("Thank you, have a nice day!")
      for i in range(999):
        if i not in self.tickets:
          ticketnumber = i
          break
      for i in range(999):
        if i not in self.parkingSpaces:
            parkingnumber = i
            break
      self.tickets.append(ticketnumber)
      self.parkingSpaces.append(parkingnumber)
    else:
      Parking_Garage.payforParking(self)

def run():
  samsparking = Parking_Garage()
  task = ' '
  while task.lower() != 'quit':
    task = input("Choose one of the following: \nTaking a ticket \nPaying for parking \nLeaving garage\nQuit\n")
    if task.lower() == 'taking a ticket':
      samsparking.takeTicket()
    elif task.lower() == "paying for parking":
      samsparking.payforParking()
    elif task.lower() == "leaving garage":
      samsparking.leaveGarage()
    else:
      print("Please type one of the options exactly as written")

run()
# Out:
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# leaving garage
# $'s paid for ticket? (Please type a number.): 2
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# leaving garage
# Thank you, have a nice day!
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# taking a ticket
# ['b', 'c', 0]
# ['b2', 'c3', 0]
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# paying for parking
# $'s paid for ticket? (Please type a number.): 2
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# leaving garage
# Thank you, have a nice day!
# Choose one of the following:
# Taking a ticket
# Paying for parking
# Leaving garage
# Quit
# paying for parking
# $'s paid for ticket? (Please type a number.): 3
# Choose one of the following:
# Taking a ticket
# Paying for parking
# ...
